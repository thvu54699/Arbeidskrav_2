# %% [markdown]
# Arbeidskrav 2   PY1010

# %%
# Oppgave 1

alder = int(input('Hvilket år er du født? ') ) 
alder = 2024 - alder

print('Du er:', alder, 'gammel')
# Out:
# Hvilket år er du født?  2000
# Du er: 24 gammel

# %%
# Oppgave 2

antall_elever = int(input('Skriv inn antall elever:' ))
pizzaer = int(antall_elever * 0.25 + 0.999)  # runder opp
print(f"Det må handles inn {pizzaer} pizzaer til festen.")
# Out:
# Skriv inn antall elever: 21
# Det må handles inn 6 pizzaer til festen.

# %%
# Oppgave 3

import numpy as np

# Funksjon som konverterer grader til radianer
def grader_til_radianer(v_grad):
    v_rad = v_grad * np.pi / 180
    return v_rad

# Hovedprogram
v_grad = float(input('Skriv inn gradtallet: '))
v_rad = grader_til_radianer(v_grad) 
print(f"{v_grad} grader tilsvarer {v_rad:.4f} radianer.")   # Skriver ut radianer med fire desimal
# Out:
# Skriv inn gradtallet:  37.3
# 37.3 grader tilsvarer 0.6510 radianer.

# %%
# Oppgave 4
# a)

data = {
    "Norge": ["Oslo", 0.634],
    "England": ["London", 8.982],
    "Franrike": ["Paris", 2.161],
    "Italia": ["Roma", 2.873]        # Justert til mill. enhet
    }

# b) Be brukeren skrive inn et land
land = input("Skriv inn et land: ")

# Sjekk om landet finnes i dictionaryen
if land in data:
    hovedstad = data[land][0]
    innbyggere = data[land][1]
    print(f"{hovedstad} er hovedstaden i {land} og det er {innbyggere} mill. innbyggere i {hovedstad}")
else:
    print("Beklager, informasjon om dette landet finnes ikke i systemet.")
# Out:
# Skriv inn et land:  Italia
# Roma er hovedstaden i Italia og det er 2.873 mill. innbyggere i Roma

# %%
# Oppgave 4
# c)

# Eksisterende dictionary
data = {
    "Norge": ["Oslo", 0.634],
    "England": ["London", 8.982],
    "Frankrike": ["Paris", 2.161],
    "Italia": ["Roma", 2.873]        # Justert til mill. enhet
}

# Be brukeren skrive inn et nytt land
nytt_land = input("Skriv inn navnet på et nytt land: ")

# Sjekk om landet allerede finnes
if nytt_land in data:
    print(f"{nytt_land} finnes allerede i systemet.")
else:
    hovedstad = input(f"Skriv inn hovedstaden i {nytt_land}: ")
    innbyggere = float(input(f"Skriv inn antall innbyggere i {hovedstad} (i millioner): "))
    try:
        #innbyggere = float(input(f"Skriv inn antall innbyggere i {hovedstad} (i millioner): "))
        
        # Legg til ny informasjon i dictionaryen
        data[nytt_land] = [hovedstad, innbyggere]
        print("\nOppdatert informasjon:")
        for land, info in data.items():
            print(f"{land}: Hovedstad = {info[0]}, Innbyggere = {info[1]} mill.")
    except ValueError:
        print("Ugyldig tallformat for innbyggere. Vennligst bruk punktum som desimal.")
# Out:
# Skriv inn navnet på et nytt land:  Finland
# Skriv inn hovedstaden i Finland:  Hensinky
# Skriv inn antall innbyggere i Hensinky (i millioner):  45.678
# Oppdatert informasjon:
# Norge: Hovedstad = Oslo, Innbyggere = 0.634 mill.
# England: Hovedstad = London, Innbyggere = 8.982 mill.
# Frankrike: Hovedstad = Paris, Innbyggere = 2.161 mill.
# Italia: Hovedstad = Roma, Innbyggere = 2.873 mill.
# Finland: Hovedstad = Hensinky, Innbyggere = 45.678 mill.

# %%
# Oppgave 5

import numpy as np

def funk_Areal_Omkrets(a, b):
    r = a / 2
    Areal_Sirkel = np.pi * r**2
    Areal_Trekant = (b * a) / 2
    Omkrets_Sirkel = 2 * np.pi * r
    c = np.sqrt(a**2 + b**2)         # Regner ut hypotenus c
    
    Areal = (Areal_Sirkel / 2) + Areal_Trekant
    Omkrets = (Omkrets_Sirkel / 2) + b + c
    return (Areal, Omkrets)

# Hoved program

a = float(input('Oppgi katet/side a: '))
b = float(input('Oppgi katet/side b: ')) 

(A, O) = funk_Areal_Omkrets(a, b)
print(f"Areal til figur er: {A:.2f} og omkrets er {O:.2f}")   # Skriver ut areal og omkrets med to desimal
# Out:
# Oppgi katet/side a:  4
# Oppgi katet/side b:  6
# Areal til figur er: 18.28 og omkrets er 19.49

# %%
# Oppgave 6

import numpy as np
import matplotlib.pyplot as plt

# Lag x-verdier
x = np.linspace(-10, 10, 200)

y = -x**2 - 5     

# Plot
plt.plot(x, y, color="red", label="f(x) = -x^2 - 5")
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Oppgave 6")
plt.axhline(0, color="black")   # x-akse
plt.axvline(0, color="black")   # y-akse
plt.legend()
plt.grid(True)
plt.show()
